# %%
intervalo = input().split(' ')
int1 = int(intervalo[0])
int2 = int(intervalo[1])
aux = 0
for juh in range(int1, int2):
  for pedro in range(2, juh):
    if (juh%pedro == 0):
      aux += 1
  if aux == 0 and juh>1:
    print(juh)
  aux = 0
# Out:
# 0 10
# 2
# 3
# 5
# 7
