# %%
entrada = int(input().strip())

if entrada < 0:
  print(f"Erro no cálculo da raiz quadrada pois número é negativo.")

else:
  print(round(entrada**0.5))
# Out:
# a
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-642b1ad87e98> in <module>()
# ----> 1 entrada = int(input().strip())
#       2
#       3 if entrada < 0:
#       4   print(f"Erro no cálculo da raiz quadrada pois número é negativo.")
#       5
#
# ValueError: invalid literal for int() with base 10: 'a'
