# %%
entrada = int(input().strip())

x = 0

dic = {}

for i in range(entrada):
  b = input().strip().split(' ')
  x += 1
  dic.update({x:(b[0],b[1])})

for a in range(entrada, 0, -1):
  print(dic[a])
# Out:
# 4
# Yan 1234-5678
# Pedro 9999-9999
# Ana 8765-4321
# Marina 8877-7788
# ('Marina', '8877-7788')
# ('Ana', '8765-4321')
# ('Pedro', '9999-9999')
# ('Yan', '1234-5678')
