# %%
def fibonacci(x):
  soma = 0
  if x < 0:
    pass
  elif x == 0:
    soma += 0
  elif x == 1:
    soma += 1
  elif x > 1:
    soma += (fibonacci(x-1) + fibonacci(x-2))
  return soma

num = int(input().strip())

print(fibonacci(num))
# Out:
# 12
# 144
