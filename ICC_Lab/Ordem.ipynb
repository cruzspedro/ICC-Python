# %%
sequencia_inicial = input().split(' ')
num1, num2, num3 = (sequencia_inicial.split(' '))
int1 = int(num1)
int2 = int(num2)
int3 = int(num3)
if int1 < int2 < int3:
  print(int1, int2, int3)
elif int2 < int1 < int3:
  print(int2, int1, int3)
elif int3 < int1 < int2:
  print(int3, int1, int2)
elif int1 < int3 < int2:
  print(int1, int3, int2)
elif int2 < int3 < int1:
  print(int2, int3, int1)
elif int3 < int2 < int1:
  print(int3, int2, int1)
else:
  print('')
# Out:
# 3 2 1
# 1 2 3
