# %%
palavra1 = input()
palavra2 = input()
if palavra1.count(palavra2) != 0:
  print('A frase contem a substring', palavra2)
else:
  print('A frase nao contem a substring', palavra2)
# Out:
# Banana
# ana
# A frase contem a substring ana
