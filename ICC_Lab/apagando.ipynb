# %%
palavra1 = input()
caractere = input()
if caractere.islower:
  caractere2 = caractere.upper()
else:
  caractere2 = caractere.lower()
dec_change = ord(caractere)
dec_change2 = ord(caractere2)
vazio = ""
dic = {dec_change: vazio, dec_change2: vazio}
print(palavra1.translate(dic))
# Out:
# ICeCE
# e
# ICC
