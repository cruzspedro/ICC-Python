# %%
def escalar(x, y, z):
  soma = 0
  for i in range(z):
    soma += x[i]*y[i]
  return '%.2f' %soma

coords = int(input().strip())

vetor1 = list(map(float,input().strip().split(' ')))
vetor2 = list(map(float,input().strip().split(' ')))

print(escalar(vetor1,vetor2,coords))
# Out:
# 4
# 0.2 0.3 -5 -2.5
# 5 0.4 -2 -2
# 16.12
