# %%
entrada = list(map(int, input().strip().split(' ')))

entrada.reverse()

print(entrada)

#Não entendi como fazer esse exercício por recursão...
# Out:
#   File "<ipython-input-21-dfe74eec738e>", line 7
#     $Não entendi como fazer por recursão$
#     ^
# SyntaxError: invalid syntax
