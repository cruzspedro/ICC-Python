# %%
def mod(x):
  if x < 0:
    return -1 * x

a = int(input())
c = int(input())
b = mod(a-c)
print(a, b, type(a), type(b))
# Out:
# 3
# 5
# 3 2 <class 'int'> <class 'int'>

# %%
a = int(input())
print(a)
# Out:
# 3
# 3
