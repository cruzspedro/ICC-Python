# %%
def potencia(x, y):
  if y < 0:
    pass
  elif y == 0:
    return 1
  elif y > 0:
    return x*potencia(x, y-1)


num = int(input().strip())

expoente = int(input().strip())

print(potencia(num, expoente))
# Out:
# 3
# 3
# 27

# %%
2
