# %%
def somapar(x):
  soma = 0
  for i in x:
    if i%2 == 0:
      soma += i
  return soma

# %%
dic = input().split(' ')

lista_int = list(map(int, dic))

print(somapar(lista_int))
# Out:
# 7 5 2 2 6 9 8 7 -1
# 18
