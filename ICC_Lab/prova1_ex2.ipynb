# %%
entrada = input().split('|')

linhas = entrada.pop()

linhas2 = entrada.pop(0)

linha1 = entrada[0]

linha2 = entrada[1]

linha3 = entrada[2]

flag = True

for i in range(5):
  if linha1[i]  == 'x' and linha2[i] == 'x' and linha3[i] == 'x':
    print('x ganhou')
    flag = False
    break

if flag == True:
  if linha1[0] == 'x' and linha2[2] == 'x' and linha3[4] == 'x':
      print('x ganhou')
      flag = False

if flag == True:
  if (linha1[0] == 'x' and linha1[2] == 'x' and linha1[4] == 'x') or (linha2[0] == 'x' and linha2[2] == 'x' and linha2[4] == 'x') or (linha3[0] == 'x' and linha3[2] == 'x' and linha3[4] == 'x'):
    print('x ganhou')
    flag = False

if flag == True:
    if linha3[0] == 'x' and linha2[2]  == 'x' and linha1[4] == 'x':
      print('x ganhou')
      flag = False

if flag == True:
  print('x perdeu')
# Out:
# |x o o|x o x|x - o|
# x ganhou
