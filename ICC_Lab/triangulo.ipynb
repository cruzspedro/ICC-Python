# %%
import math

lados_triangulo = (input()).split(' ')
if lados_triangulo[0] == lados_triangulo[1] == lados_triangulo[2]:
  print('equilatero')
elif lados_triangulo[0] == lados_triangulo[1] != lados_triangulo[2] or lados_triangulo[0] == lados_triangulo[2] != lados_triangulo[1] or lados_triangulo[1] == lados_triangulo[2] != lados_triangulo[0]:
  print('isosceles')
else :
  print('escaleno')
# Out:
# 10 15 13
# escaleno
