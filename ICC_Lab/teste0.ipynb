# %%
intervalo = list(map(int, input().split(' ')))
count = 0
for i in range(intervalo[0], intervalo[1]):
  for x in range(2, i):
    if i % x == 0:
      count += 1
  if count == 0:
    print(i)
  count = 0
# Out:
# 10 20
# 11
# 13
# 17
# 19
