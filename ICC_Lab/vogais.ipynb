# %%
txt = input()
{65, 69, 73, 79, 85}
vazio = '*'
dic = {97: vazio, 101: vazio, 105: vazio, 111:vazio, 117: vazio, 65: vazio, 69: vazio, 73: vazio, 79: vazio, 85: vazio}
print(txt.translate(dic))
# Out:
# Faça um programa que leia um vetor de caracteres
# F*ç* *m pr*gr*m* q** l*** *m v*t*r d* c*r*ct*r*s
