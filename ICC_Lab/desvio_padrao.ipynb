# %%
num = int(input().strip())

lista = list(map(float, input().strip().split(' ')))

media = 0

for i in range(num):
  media += lista[i]/num

aux = 0

for i in range(num):
  aux += ((lista[i]-media)**2)/(num-1)

desvpad = aux**0.5

print(f'{desvpad:.2f}')
# Out:
# 123 456 789 123 456 789
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-3c951e61193f> in <module>
# ----> 1 num = int(input().strip())
#       2
#       3 lista = list(map(float, input().strip().split(' ')))
#       4
#       5 media = 0
#
# ValueError: invalid literal for int() with base 10: '123 456 789 123 456 789'
