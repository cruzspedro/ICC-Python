# %%
num1 = int(input())
num2 = int(input())
num3 = int(input())
num4 = int(input())

if num1%2 == 0:
  par1 = num1
else:
  par1 = 0
if num2%2 == 0:
  par2 = num2
else:
  par2 = 0
if num3%2 == 0:
  par3 = num3
else:
  par3 = 0
if num4%2 == 0:
  par4 = num4
else:
  par4 = 0

soma = par1 + par2 + par3 + par4
print('A soma dos numeros pares é', soma)
# Out:
# 12
# 66
# 4
# 2
# A soma dos números pares é 84
