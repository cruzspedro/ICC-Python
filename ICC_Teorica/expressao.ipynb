# %%
def expressao(x,y,z):
  if y != 0:
    return round(x*(2/y)+(9+z*8), 1)
  else:
    return 'Impossível'

# %%
lista = []

for i in range(3):
  lista.append(float(input()))

resultado = expressao(lista[0], lista[1], lista[2])

print(resultado)
# Out:
# 0
# 0
# 0
# Impossível
