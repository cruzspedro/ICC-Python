# %%
def maior(x,y):
  maior = x[0]
  for i in range(1, len(x)):
    if maior >= x[i]:
      pass
    else:
      maior = x[i]
  for _ in range(len(y)):
    if maior >= y[_]:
      pass
    else:
      maior = y[_]
  return maior

def menor(x,y):
  menor = x[0]
  for i in range(1, len(x)):
    if menor <= x[i]:
      pass
    else:
      menor = x[i]
  for _ in range(len(y)):
    if menor <= y[_]:
      pass
    else:
      menor = y[_]
  return menor

def intersec(x,y):
  aux = []
  for i in range(len(x)):
    for _ in range(len(y)):
      if x[i] == y[_]:
        aux.append(x[i])
      else: 
        pass
  return aux

def imprimir(x):
  aux = ''
  for i in range(len(x)):
    aux += f'{x[i]} '
  return aux
N1 = int(input().strip())

N2 = int(input().strip())

vetor1 = list(map(int,input().strip().split(' ')))

vetor2 = list(map(int,input().strip().split(' ')))

print('Intersecção:', f'{imprimir(intersec(vetor1,vetor2))}', 'Menor:', f'{menor(vetor1,vetor2)}', 'Maior:', f'{maior(vetor1,vetor2)}', sep='\n')
# Out:
# 1
# 8
# 6
# 2 4 6 8 9 1 3 7
# Intersecção:
# 6
# Menor:
# 1
# Maior:
# 9
