# %%
num = int(input())

def perfeito(x):
  soma = 0
  for i in range(1, x):
    if x%i == 0:
      soma += i
  if x == soma:
    print('Sim')
  else:
    print('Não')
  
perfeito(num)
# Out:
# 496
# Sim
